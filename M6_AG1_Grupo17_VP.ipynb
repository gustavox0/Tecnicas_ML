# %% [markdown]
# <a href="https://colab.research.google.com/github/gustavox0/Tecnicas_ML/blob/main/M6_AG1_Grupo17_VP.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Contexto
#
# IMDb es una de las mayores bases de datos de películas del mundo. A través de su sitio web es posible acceder a títulos, sinopsis, géneros, fechas de estreno y puntuaciones de millones de películas. En esta práctica, no se utilizará un dataset preexistente, sino que el alumno deberá **construir su propio dataset mediante web scraping**.
#
# Se pide:
#
# Con los datos recogidos, se entrenarán tres modelos supervisados de clasificación, todos ellos a partir del texto de la película: el título, la sinopsis o ambos.
#
#   - Utilizar la página de exploración de géneros de IMDb: https://www.imdb.com/search/title/?explore=genres para extraer los siguientes datos para cada película:
#     - Título
#     - Sinopsis (texto resumen)
#     - Fecha de estreno
#     - Género principal
#     - Puntuación media de IMDb.
#
# Se deben obtener al menos 5 géneros distintos.
#
# El número de películas por género queda a elección del alumno, pero se valorará reflexionar (y/o experimentar) sobre como influye el tamaño del dataset en la calidad del modelo.

# %% [markdown]
# # **Carga y exploración inicial del dataset**
#
#
# **Creacion del DATASET**
#
# Para la búsqueda y descarga de información, recurrimos a una estrategia de webscrapping. Para ello, utilizamos la API de OMDb.
# Esta API se puede utilizar en una versión gratuita que permite la descarga de 1000 registros por día.

# %%
import requests
import pandas as pd
import time
from random import uniform

# API Key de OMDb
OMDB_API_KEY = "ff59522d" #Si quieres generar un API key y correr el código puedes hacerlo aquí https://www.omdbapi.com/apikey.aspx

# Géneros que queremos obtener
GENRES = ['Action', 'Comedy', 'Drama', 'Horror', 'Sci-Fi']
MOVIES_PER_GENRE = 200
SEARCH_TERMS = ['a', 'e', 'the', 'life', 'love', 'dark', 'war', 'night'] #Dado que IMDb no permite búsqueda por género, ampliamos la busqueda con estos términos
OUTPUT_FILE = "dataset_movies.csv" #guardar datos en csv

def fetch_movie_details(imdb_id): #Funcion para consultar los detalles de la película por su ID
    url = f"http://www.omdbapi.com/?apikey={OMDB_API_KEY}&i={imdb_id}&plot=short"
    try:
        response = requests.get(url)
        return response.json()
    except Exception as e:
        print(f" Error al obtener detalles de {imdb_id}: {e}")
        return None

def get_movies_by_genre(target_genre, max_movies=200): #Funcion para buscar película por género
    collected = [] #para guardar listado de películas encontradas
    seen_ids = set()

    for term in SEARCH_TERMS:
        for page in range(1, 11):  # hasta 10 páginas por término de búsqueda
            if len(collected) >= max_movies: #si alcanza el número de pelis (200) de detiene la función
                return collected

            url = f"http://www.omdbapi.com/?apikey={OMDB_API_KEY}&s={term}&type=movie&page={page}" #llamada a API
            try:
                res = requests.get(url)
                search_data = res.json()
            except Exception as e:
                print(f" Error al buscar películas con término '{term}' (página {page}): {e}")
                break

            if search_data.get('Response') != 'True':
                break  # sin más resultados válidos

            for item in search_data.get('Search', []):
                imdb_id = item.get('imdbID')
                if not imdb_id or imdb_id in seen_ids:
                    continue

                movie_data = fetch_movie_details(imdb_id) #llama a función de detalles de película
                if not movie_data:
                    continue

                genres = movie_data.get('Genre', '') #filtra a películas de los géneros buscados.
                if target_genre not in genres:
                    continue

                collected.append({                     #guarda la info deseada de cada película
                    'Título': movie_data.get('Title'),
                    'Sinopsis': movie_data.get('Plot'),
                    'Fecha de estreno': movie_data.get('Released'),
                    'Género principal': target_genre,
                    'Puntuación IMDb': movie_data.get('imdbRating')
                })

                seen_ids.add(imdb_id)
                print(f"[{target_genre}] {len(collected)}. {movie_data.get('Title')}")

                if len(collected) >= max_movies:
                    break

                time.sleep(uniform(0.4, 0.8))  # espera entre consultas para evitar bloqueo de la página

            time.sleep(uniform(0.8, 1.5))

    return collected

# Ejecutar la búsqueda por todos los géneros
all_movies = []
for genre in GENRES:
    print(f"\n Buscando películas del género: {genre}")
    movies = get_movies_by_genre(genre, MOVIES_PER_GENRE)
    all_movies.extend(movies)

# Guardar resultados en CSV
df = pd.DataFrame(all_movies)
df.to_csv(OUTPUT_FILE, index=False)
print(f"\n {len(df)} películas guardadas en {OUTPUT_FILE}")
# Out:
#  Buscando películas del género: Action
# [Action] 1. The Life Aquatic with Steve Zissou
# [Action] 2. Bad Boys for Life
# [Action] 3. Lara Croft: Tomb Raider - The Cradle of Life
# [Action] 4. Proof of Life
# [Action] 5. A Bittersweet Life
# [Action] 6. Term Life
# [Action] 7. Thor: Love and Thunder
# [Action] 8. Love and Monsters
# [Action] 9. From Russia with Love
# [Action] 10. From Paris with Love
# [Action] 11. Love Exposure
# [Action] 12. I Love Trouble
# [Action] 13. Love Hurts
# [Action] 14. The Dark Knight
# [Action] 15. The Dark Knight Rises
# [Action] 16. Thor: The Dark World
# [Action] 17. Transformers: Dark of the Moon
# [Action] 18. X-Men: Dark Phoenix
# [Action] 19. Terminator: Dark Fate
# [Action] 20. The Dark Tower
# [Action] 21. Batman: The Dark Knight Returns, Part 1
# [Action] 22. Under Siege 2: Dark Territory
# [Action] 23. Alone in the Dark
# [Action] 24. Batman: The Dark Knight Returns, Part 2
# [Action] 25. Hold the Dark
# [Action] 26. Justice League Dark
# [Action] 27. Justice League Dark: Apokolips War
# [Action] 28. The Dark Valley
# [Action] 29. Dark Angel
# [Action] 30. Monsters: Dark Continent
# [Action] 31. The Chronicles of Riddick: Dark Fury
# [Action] 32. Dark Tide
# [Action] 33. Rumble Through the Dark
# [Action] 34. Dark Floors
# [Action] 35. A Dark Truth
# [Action] 36. Dark Blue World
# [Action] 37. Dark Planet
# [Action] 38. Against the Dark
# [Action] 39. Avengers: Infinity War
# [Action] 40. Captain America: Civil War
# [Action] 41. World War Z
# [Action] 42. War of the Worlds
# [Action] 43. War for the Planet of the Apes
# [Action] 44. Civil War
# [Action] 45. The Tomorrow War
# [Action] 46. This Means War
# [Action] 47. The Huntsman: Winter's War
# [Action] 48. War
# [Action] 49. Punisher: War Zone
# [Action] 50. Casualties of War
# [Action] 51. Tae Guk Gi: The Brotherhood of War
# [Action] 52. The War of the Worlds
# [Action] 53. War
# [Action] 54. Tomorrow, When the War Began
# [Action] 55. The Lord of the Rings: The War of the Rohirrim
# [Action] 56. Justice League: War
# [Action] 57. The Art of War
# [Action] 58. Max Manus: Man of War
# [Action] 59. Dragon Wars: D-War
# [Action] 60. War, Inc.
# [Action] 61. War on Everyone
# [Action] 62. No War
# [Action] 63. 5 Days of War
# [Action] 64. War of the Arrows
# [Action] 65. Drug War
# [Action] 66. Fortress of War
# [Action] 67. The Dogs of War
# [Action] 68. Justice Society: World War II
# [Action] 69. War
# [Action] 70. Cold War
# [Action] 71. Men of War
# [Action] 72. Left Behind III: World at War
# [Action] 73. Future War
# [Action] 74. War of the Worlds 2: The Next Wave
# [Action] 75. Kickboxer 3: The Art of War
# [Action] 76. War Pigs
# [Action] 77. The War of the Gargantuas
# [Action] 78. The Art of War II: Betrayal
# [Action] 79. Boudica: Queen of War
# [Action] 80. 15 Minutes of War
# [Action] 81. Cold War 2
# [Action] 82. Men in War
# [Action] 83. Game Night
# [Action] 84. Run All Night
# [Action] 85. Fright Night
# [Action] 86. Violent Night
# [Action] 87. We Own the Night
# [Action] 88. Werewolf by Night
# [Action] 89. Friday Night Lights
# [Action] 90. Live by Night
# [Action] 91. Night Watch
# [Action] 92. The Night Comes for Us
# [Action] 93. Night Hunter
# [Action] 94. Shark Night
# [Action] 95. Silent Night
# [Action] 96. Night Teeth
# [Action] 97. Judgment Night
# [Action] 98. Dylan Dog: Dead of Night
# [Action] 99. Into the Night
# [Action] 100. Survive the Night
# [Action] 101. Cold Comes the Night
#
#  Buscando películas del género: Comedy
# [Comedy] 1. Life Is Beautiful
# [Comedy] 2. Monty Python's Life of Brian
# [Comedy] 3. The Secret Life of Walter Mitty
# [Comedy] 4. A Bug's Life
# [Comedy] 5. The Secret Life of Pets
# [Comedy] 6. The Life Aquatic with Steve Zissou
# [Comedy] 7. Bad Boys for Life
# [Comedy] 8. Life as We Know It
# [Comedy] 9. Monty Python's the Meaning of Life
# [Comedy] 10. Dan in Real Life
# [Comedy] 11. The Book of Life
# [Comedy] 12. The Secret Life of Pets 2
# [Comedy] 13. Life
# [Comedy] 14. The Odd Life of Timothy Green
# [Comedy] 15. Life of the Party
# [Comedy] 16. A Life Less Ordinary
# [Comedy] 17. My Life as a Zucchini
# [Comedy] 18. Life or Something Like It
# [Comedy] 19. The Life List
# [Comedy] 20. Life After Beth
# [Comedy] 21. Private Life
# [Comedy] 22. My Life as a Dog
# [Comedy] 23. David Brent: Life on the Road
# [Comedy] 24. Defending Your Life
# [Comedy] 25. My Life in Ruins
# [Comedy] 26. Life of Crime
# [Comedy] 27. The Life and Death of Peter Sellers
# [Comedy] 28. The Private Life of Sherlock Holmes
# [Comedy] 29. Life Is a Miracle
# [Comedy] 30. Life in a Metro
# [Comedy] 31. The Easy Life
# [Comedy] 32. Dead Like Me: Life After Death
# [Comedy] 33. Last Life in the Universe
# [Comedy] 34. Life Stinks
# [Comedy] 35. Life Is Sweet
# [Comedy] 36. Middle School: The Worst Years of My Life
# [Comedy] 37. A Dog's Life
# [Comedy] 38. Train of Life
# [Comedy] 39. The Life and Times of Judge Roy Bean
# [Comedy] 40. Life Partners
# [Comedy] 41. Life-Size
# [Comedy] 42. Cunk on Life
# [Comedy] 43. Life Happens
# [Comedy] 44. Crazy, Stupid, Love.
# [Comedy] 45. Love Actually
# [Comedy] 46. Dr. Strangelove or: How I Learned to Stop Worrying and Love the Bomb
# [Comedy] 47. Thor: Love and Thunder
# [Comedy] 48. Shakespeare in Love
# [Comedy] 49. Love & Other Drugs
# [Comedy] 50. P.S. I Love You
# [Comedy] 51. I Love You, Man
# [Comedy] 52. Punch-Drunk Love
# [Comedy] 53. Love, Rosie
# [Comedy] 54. Love and Monsters
# [Comedy] 55. Love, Simon
# [Comedy] 56. I Love You Phillip Morris
# [Comedy] 57. Stuck in Love.
# [Comedy] 58. To Rome with Love
# [Comedy] 59. Love Me If You Dare
# [Comedy] 60. A Lot Like Love
# [Comedy] 61. Love Hard
# [Comedy] 62. Wristcutters: A Love Story
# [Comedy] 63. Show Me Love
# [Comedy] 64. The Love Guru
# [Comedy] 65. New York, I Love You
# [Comedy] 66. To All the Boys: P.S. I Still Love You
# [Comedy] 67. Down with Love
# [Comedy] 68. The One I Love
# [Comedy] 69. American Pie Presents: The Book of Love
# [Comedy] 70. Can't Buy Me Love
# [Comedy] 71. Love and Death
# [Comedy] 72. Everyone Says I Love You
# [Comedy] 73. I Love You, Beth Cooper
# [Comedy] 74. Must Love Dogs
# [Comedy] 75. Love the Coopers
# [Comedy] 76. Love & Friendship
# [Comedy] 77. Seeking True Love
# [Comedy] 78. Addicted to Love
# [Comedy] 79. Toilet: A Love Story
# [Comedy] 80. Falling Inn Love
# [Comedy] 81. Love Wedding Repeat
# [Comedy] 82. The Love Witch
# [Comedy] 83. Love, Guaranteed
# [Comedy] 84. The Love Bug
# [Comedy] 85. Love in the Afternoon
# [Comedy] 86. I Think I Love My Wife
# [Comedy] 87. Love Again
# [Comedy] 88. Love Aaj Kal
# [Comedy] 89. Love Exposure
# [Comedy] 90. The Love Punch
# [Comedy] 91. Love Today
# [Comedy] 92. I Love You to Death
# [Comedy] 93. For Love or Money
# [Comedy] 94. Love Potion No. 9
# [Comedy] 95. Love Is All You Need
# [Comedy] 96. Love and Other Disasters
# [Comedy] 97. Love in the Villa
# [Comedy] 98. Last Love
# [Comedy] 99. I Love Trouble
# [Comedy] 100. Love Hurts
# [Comedy] 101. Puppy Love
# [Comedy] 102. What's Love Got to Do with It?
# [Comedy] 103. Transformers: Dark of the Moon
# [Comedy] 104. Dark Shadows
# [Comedy] 105. You Will Meet a Tall Dark Stranger
# [Comedy] 106. A Shot in the Dark
# [Comedy] 107. Dark Star
# [Comedy] 108. Elvira: Mistress of the Dark
# [Comedy] 109. Orion and the Dark
# [Comedy] 110. The Old Dark House
# [Comedy] 111. Dark Blue Almost Black
# [Comedy] 112. Dark Habits
# [Comedy] 113. Talkin' Dirty After Dark
# [Comedy] 114. Dark Horse
# [Comedy] 115. Jimmy Carr: His Dark Material
# [Comedy] 116. Trevor Noah: Afraid of the Dark
# [Comedy] 117. The Dark Side of the Heart
# [Comedy] 118. The Dark Backward
# [Comedy] 119. War Dogs
# [Comedy] 120. This Means War
# [Comedy] 121. Charlie Wilson's War
# [Comedy] 122. The War of the Roses
# [Comedy] 123. War Machine
# [Comedy] 124. The War with Grandpa
# [Comedy] 125. War, Inc.
# [Comedy] 126. War on Everyone
# [Comedy] 127. Woman at War
# [Comedy] 128. I Was a Male War Bride
# [Comedy] 129. The Milagro Beanfield War
# [Comedy] 130. Trojan War
# [Comedy] 131. The Great War
# [Comedy] 132. How I Unleashed World War II
# [Comedy] 133. Oh! What a Lovely War
# [Comedy] 134. Kaguya-sama: Love Is War - The First Kiss That Never Ends
# [Comedy] 135. Night at the Museum
# [Comedy] 136. Game Night
# [Comedy] 137. Night at the Museum: Battle of the Smithsonian
# [Comedy] 138. Date Night
# [Comedy] 139. Night at the Museum: Secret of the Tomb
# [Comedy] 140. It Happened One Night
# [Comedy] 141. Fright Night
# [Comedy] 142. Violent Night
# [Comedy] 143. The Night Before
# [Comedy] 144. Two Night Stand
# [Comedy] 145. Night on Earth
# [Comedy] 146. A Night at the Roxbury
# [Comedy] 147. Rough Night
# [Comedy] 148. A Hard Day's Night
# [Comedy] 149. Night School
# [Comedy] 150. Late Night
# [Comedy] 151. A Night at the Opera
# [Comedy] 152. Saturday Night
# [Comedy] 153. One Night at McCool's
# [Comedy] 154. Night of the Creeps
# [Comedy] 155. Night of the Comet
# [Comedy] 156. About Last Night
# [Comedy] 157. Day for Night
# [Comedy] 158. Silent Night
# [Comedy] 159. Night of the Demons
# [Comedy] 160. Day & Night
# [Comedy] 161. Night Shift
# [Comedy] 162. About Last Night
# [Comedy] 163. Dylan Dog: Dead of Night
# [Comedy] 164. Fright Night Part 2
# [Comedy] 165. My Night at Maud's
# [Comedy] 166. Smiles of a Summer Night
# [Comedy] 167. Moms' Night Out
# [Comedy] 168. Into the Night
# [Comedy] 169. A Royal Night Out
# [Comedy] 170. Last Night
# [Comedy] 171. Silent Night
#
#  Buscando películas del género: Drama
# [Drama] 1. Life Is Beautiful
# [Drama] 2. Life of Pi
# [Drama] 3. It's a Wonderful Life
# [Drama] 4. The Secret Life of Walter Mitty
# [Drama] 5. The Tree of Life
# [Drama] 6. Life as We Know It
# [Drama] 7. The Life of David Gale
# [Drama] 8. Dan in Real Life
# [Drama] 9. Waking Life
# [Drama] 10. Proof of Life
# [Drama] 11. This Boy's Life
# [Drama] 12. Life
# [Drama] 13. The Double Life of Véronique
# [Drama] 14. The Odd Life of Timothy Green
# [Drama] 15. The Goat Life
# [Drama] 16. Life as a House
# [Drama] 17. A Bittersweet Life
# [Drama] 18. High Life
# [Drama] 19. After.Life
# [Drama] 20. One Life
# [Drama] 21. An Unfinished Life
# [Drama] 22. My Life as a Zucchini
# [Drama] 23. A Hidden Life
# [Drama] 24. The Secret Life of Bees
# [Drama] 25. The Life List
# [Drama] 26. A Matter of Life and Death
# [Drama] 27. My Life Without Me
# [Drama] 28. Life Itself
# [Drama] 29. Private Life
# [Drama] 30. My Life as a Dog
# [Drama] 31. Defending Your Life
# [Drama] 32. The Electrical Life of Louis Wain
# [Drama] 33. Imitation of Life
# [Drama] 34. Life and a Day
# [Drama] 35. The Life and Death of Colonel Blimp
# [Drama] 36. A Better Life
# [Drama] 37. Light of My Life
# [Drama] 38. The Life Ahead
# [Drama] 39. Life in a Day
# [Drama] 40. Mishima: A Life in Four Chapters
# [Drama] 41. The Life and Death of Peter Sellers
# [Drama] 42. The 9th Life of Louis Drax
# [Drama] 43. The Life Before Her Eyes
# [Drama] 44. Stuart: A Life Backwards
# [Drama] 45. After Life
# [Drama] 46. Life Is a Dream
# [Drama] 47. The Secret Life of Words
# [Drama] 48. Life in a Metro
# [Drama] 49. The Easy Life
# [Drama] 50. Dead Like Me: Life After Death
# [Drama] 51. Lust for Life
# [Drama] 52. My Life
# [Drama] 53. City of Life and Death
# [Drama] 54. Strange Way of Life
# [Drama] 55. Last Life in the Universe
# [Drama] 56. Life Is Sweet
# [Drama] 57. Life in a Year
# [Drama] 58. Gainsbourg: A Heroic Life
# [Drama] 59. A Dog's Life
# [Drama] 60. Invisible Life
# [Drama] 61. The First Day of the Rest of Your Life
# [Drama] 62. Married Life
# [Drama] 63. Train of Life
# [Drama] 64. The Life and Times of Judge Roy Bean
# [Drama] 65. Life Partners
# [Drama] 66. The Life of Emile Zola
# [Drama] 67. Still Life
# [Drama] 68. Life
# [Drama] 69. A Beautiful Life
# [Drama] 70. Term Life
# [Drama] 71. Bigger Than Life
# [Drama] 72. Life of a King
# [Drama] 73. Crazy, Stupid, Love.
# [Drama] 74. Love Actually
# [Drama] 75. Shakespeare in Love
# [Drama] 76. Love & Other Drugs
# [Drama] 77. P.S. I Love You
# [Drama] 78. Punch-Drunk Love
# [Drama] 79. In the Mood for Love
# [Drama] 80. Love, Simon
# [Drama] 81. Eat Pray Love
# [Drama] 82. Stuck in Love.
# [Drama] 83. Love Me If You Dare
# [Drama] 84. A Lot Like Love
# [Drama] 85. Love
# [Drama] 86. Wristcutters: A Love Story
# [Drama] 87. Love Lies Bleeding
# [Drama] 88. Show Me Love
# [Drama] 89. New York, I Love You
# [Drama] 90. Endless Love
# [Drama] 91. To All the Boys: P.S. I Still Love You
# [Drama] 92. Sea of Love
# [Drama] 93. The One I Love
# [Drama] 94. Can't Buy Me Love
# [Drama] 95. Love & Mercy
# [Drama] 96. Love at First Sight
# [Drama] 97. Love Story
# [Drama] 98. For Love of the Game
# [Drama] 99. Bob Marley: One Love
# [Drama] 100. Love Happens
# [Drama] 101. A Love Song for Bobby Long
# [Drama] 102. A Short Film About Love
# [Drama] 103. Love & Friendship
# [Drama] 104. Love at First Sight
# [Drama] 105. What's Love Got to Do with It
# [Drama] 106. Love & Basketball
# [Drama] 107. I Am Love
# [Drama] 108. Love in the Time of Cholera
# [Drama] 109. Toilet: A Love Story
# [Drama] 110. If Anything Happens I Love You
# [Drama] 111. My Summer of Love
# [Drama] 112. To Sir, with Love
# [Drama] 113. Love Likes Coincidences
# [Drama] 114. The Edge of Love
# [Drama] 115. The Consequences of Love
# [Drama] 116. Love in the Afternoon
# [Drama] 117. I Think I Love My Wife
# [Drama] 118. Redeeming Love
# [Drama] 119. Love Again
# [Drama] 120. Feast of Love
# [Drama] 121. Love Aaj Kal
# [Drama] 122. Love Exposure
# [Drama] 123. Falling in Love
# [Drama] 124. Love Today
# [Drama] 125. For Love or Money
# [Drama] 126. Love Is All You Need
# [Drama] 127. Love and Other Disasters
# [Drama] 128. Hounds of Love
# [Drama] 129. Like Someone in Love
# [Drama] 130. Last Love
# [Drama] 131. Love Is Strange
# [Drama] 132. Love Li
# [Drama] 133. Love Letter
# [Drama] 134. The Strange Love of Martha Ivers
# [Drama] 135. Forgotten Love
# [Drama] 136. What's Love Got to Do with It?
# [Drama] 137. The Dark Knight
# [Drama] 138. The Dark Knight Rises
# [Drama] 139. Zero Dark Thirty
# [Drama] 140. Dancer in the Dark
# [Drama] 141. Dark Waters
# [Drama] 142. Dark Water
# [Drama] 143. Batman: The Dark Knight Returns, Part 1
# [Drama] 144. Dark Places
# [Drama] 145. You Will Meet a Tall Dark Stranger
# [Drama] 146. Batman: The Dark Knight Returns, Part 2
# [Drama] 147. Hold the Dark
# [Drama] 148. Dark Water
# [Drama] 149. Super Dark Times
# [Drama] 150. Dark Blue
# [Drama] 151. After the Dark
# [Drama] 152. A Dark Song
# [Drama] 153. Dark Crimes
# [Drama] 154. The Seeker: The Dark Is Rising
# [Drama] 155. Down a Dark Hall
# [Drama] 156. The Dark Valley
# [Drama] 157. The Old Dark House
# [Drama] 158. Dark Victory
# [Drama] 159. A Dark Foe
# [Drama] 160. The Dark
# [Drama] 161. Monsters: Dark Continent
# [Drama] 162. A Cry in the Dark
# [Drama] 163. Dark Was the Night
# [Drama] 164. Dark Tide
# [Drama] 165. Rumble Through the Dark
# [Drama] 166. Out in the Dark
# [Drama] 167. Dark Blue Almost Black
# [Drama] 168. Dark Habits
# [Drama] 169. The Dark Horse
# [Drama] 170. Dark Horse
# [Drama] 171. A Dark Truth
# [Drama] 172. The Dark
# [Drama] 173. Dark Blue World
# [Drama] 174. The Dark Mirror
# [Drama] 175. The Dark Corner
# [Drama] 176. The Dark House
# [Drama] 177. Dark River
# [Drama] 178. After Dark, My Sweet
# [Drama] 179. The Dark Side of the Heart
# [Drama] 180. Lord of War
# [Drama] 181. War for the Planet of the Apes
# [Drama] 182. The Tomorrow War
# [Drama] 183. War Horse
# [Drama] 184. Charlie Wilson's War
# [Drama] 185. The Huntsman: Winter's War
# [Drama] 186. Punisher: War Zone
# [Drama] 187. Cold War
# [Drama] 188. The Flowers of War
# [Drama] 189. Hart's War
# [Drama] 190. War Machine
# [Drama] 191. Casualties of War
# [Drama] 192. Ayla: The Daughter of War
# [Drama] 193. Tae Guk Gi: The Brotherhood of War
# [Drama] 194. Munich: The Edge of War
# [Drama] 195. The Current War
# [Drama] 196. Tomorrow, When the War Began
# [Drama] 197. The War with Grandpa
# [Drama] 198. Dragon Wars: D-War
# [Drama] 199. The Vaccine War
# [Drama] 200. A Private War
#
#  Buscando películas del género: Horror
# [Horror] 1. Life
# [Horror] 2. Life After Beth
# [Horror] 3. All the Boys Love Mandy Lane
# [Horror] 4. The Love Witch
# [Horror] 5. Dark Shadows
# [Horror] 6. Scary Stories to Tell in the Dark
# [Horror] 7. Dark Skies
# [Horror] 8. Dark Water
# [Horror] 9. Don't Be Afraid of the Dark
# [Horror] 10. Alone in the Dark
# [Horror] 11. Batman: The Dark Knight Returns, Part 2
# [Horror] 12. Near Dark
# [Horror] 13. Unfriended: Dark Web
# [Horror] 14. Dark Water
# [Horror] 15. The Dark and the Wicked
# [Horror] 16. Justice League Dark
# [Horror] 17. A Dark Song
# [Horror] 18. Elvira: Mistress of the Dark
# [Horror] 19. The Dark Half
# [Horror] 20. Down a Dark Hall
# [Horror] 21. Dark Angel
# [Horror] 22. 30 Days of Night: Dark Days
# [Horror] 23. A Dark Foe
# [Horror] 24. The Dark
# [Horror] 25. Dark Was the Night
# [Horror] 26. Dark Harvest
# [Horror] 27. Dark Night of the Scarecrow
# [Horror] 28. Coming Home in the Dark
# [Horror] 29. Alone in the Dark
# [Horror] 30. Dark Floors
# [Horror] 31. Dark Ride
# [Horror] 32. The Dark
# [Horror] 33. The Dark Hours
# [Horror] 34. Against the Dark
# [Horror] 35. Alone in the Dark II
# [Horror] 36. Out of the Dark
# [Horror] 37. Dark Glasses
# [Horror] 38. Dark Cloud
# [Horror] 39. Dark Touch
# [Horror] 40. Dark Circles
# [Horror] 41. Dark Moon Rising
# [Horror] 42. Don't Be Afraid of the Dark
# [Horror] 43. A Blade in the Dark
# [Horror] 44. One Dark Night
# [Horror] 45. World War Z
# [Horror] 46. Ghosts of War
# [Horror] 47. War of the Worlds 2: The Next Wave
# [Horror] 48. The War of the Gargantuas
# [Horror] 49. War of the Worlds: The Attack
# [Horror] 50. 30 Days of Night
# [Horror] 51. Last Night in Soho
# [Horror] 52. Night of the Living Dead
# [Horror] 53. Late Night with the Devil
# [Horror] 54. It Comes at Night
# [Horror] 55. Fright Night
# [Horror] 56. The Night House
# [Horror] 57. Night Watch
# [Horror] 58. Night of the Living Dead
# [Horror] 59. A Girl Walks Home Alone at Night
# [Horror] 60. Prom Night
# [Horror] 61. The Strangers: Prey at Night
# [Horror] 62. Night Swim
# [Horror] 63. Shark Night
# [Horror] 64. Night of the Creeps
# [Horror] 65. Night of the Comet
# [Horror] 66. Silent Night
# [Horror] 67. Prom Night
# [Horror] 68. Night of the Demons
# [Horror] 69. Silent Night, Deadly Night
# [Horror] 70. The Night Eats the World
# [Horror] 71. The Night Listener
# [Horror] 72. Dead of Night
# [Horror] 73. Fright Night Part 2
# [Horror] 74. The Night Flier
# [Horror] 75. Last the Night
# [Horror] 76. Night Train
# [Horror] 77. Silent Night
#
#  Buscando películas del género: Sci-Fi
# [Sci-Fi] 1. Life
# [Sci-Fi] 2. High Life
# [Sci-Fi] 3. Light of My Life
# [Sci-Fi] 4. Dark City
# [Sci-Fi] 5. X-Men: Dark Phoenix
# [Sci-Fi] 6. Terminator: Dark Fate
# [Sci-Fi] 7. Dark Skies
# [Sci-Fi] 8. Alone in the Dark
# [Sci-Fi] 9. Batman: The Dark Knight Returns, Part 2
# [Sci-Fi] 10. Dark Star
# [Sci-Fi] 11. Justice League Dark
# [Sci-Fi] 12. Justice League Dark: Apokolips War
# [Sci-Fi] 13. Monsters: Dark Continent
# [Sci-Fi] 14. The Chronicles of Riddick: Dark Fury
# [Sci-Fi] 15. Dark Planet
# [Sci-Fi] 16. Against the Dark
# [Sci-Fi] 17. Dark Encounter
# [Sci-Fi] 18. Dark Cloud
# [Sci-Fi] 19. Avengers: Infinity War
# [Sci-Fi] 20. Captain America: Civil War
# [Sci-Fi] 21. War of the Worlds
# [Sci-Fi] 22. The War of the Worlds
# [Sci-Fi] 23. Justice League: War
# [Sci-Fi] 24. Future War
# [Sci-Fi] 25. War of the Worlds 2: The Next Wave
# [Sci-Fi] 26. The War of the Gargantuas
# [Sci-Fi] 27. War of the Worlds: The Attack
# [Sci-Fi] 28. The Vast of Night
# [Sci-Fi] 29. Night of the Creeps
# [Sci-Fi] 30. Night of the Comet
#
#  579 películas guardadas en dataset_movies.csv

# %% [markdown]
# La busqueda anterior genera el archivo csv "dataset_movies.csv". Por el límite diario que permite la API de OMDb de manera gratuita (1000 registros), a partir de acá guardamos el archivo generado y trabajemos con el para no realizar el webscrapping cada vez.

# %%
# Base generada mediante webscrapping
dataset = pd.read_csv("https://raw.githubusercontent.com/gustavox0/Tecnicas_ML/refs/heads/main/dataset_movies.csv")
dataset.head()
# Out:
#                                          Título  \
# 0            The Life Aquatic with Steve Zissou
# 1                             Bad Boys for Life
# 2  Lara Croft: Tomb Raider - The Cradle of Life
# 3                                 Proof of Life
# 4                            A Bittersweet Life
#
#                                             Sinopsis Fecha de estreno  \
# 0  With a plan to exact revenge on a legendary sh...      25 Dec 2004
# 1  Miami detectives Mike Lowrey and Marcus Burnet...      17 Jan 2020
# 2  Lara Croft sets out on a quest to prevent Pand...      25 Jul 2003
# 3  Alice hires a professional negotiator to obtai...      08 Dec 2000
# 4  Things go wrong for a high ranking mobster whe...      01 Apr 2005
#
#   Género principal  Puntuación IMDb
# 0           Action              7.2
# 1           Action              6.5
# 2           Action              5.5
# 3           Action              6.3
# 4           Action              7.5

# %%
#Resumen de la base
print(dataset.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 579 entries, 0 to 578
# Data columns (total 5 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Título            579 non-null    object
#  1   Sinopsis          579 non-null    object
#  2   Fecha de estreno  578 non-null    object
#  3   Género principal  579 non-null    object
#  4   Puntuación IMDb   577 non-null    float64
# dtypes: float64(1), object(4)
# memory usage: 22.7+ KB
# None

# %% [markdown]
# Como puede observarse, el dataset contiene la información de 579 películas y los atributos Título, Sinópsis, Fecha de estreno, Género de película y
# Puntuación IMDb.

# %%
# Películas por género
print(round(dataset['Género principal'].value_counts(normalize=True) * 100,2))
# Out:
# Género principal
# Drama     34.54
# Comedy    29.53
# Action    17.44
# Horror    13.30
# Sci-Fi     5.18
# Name: proportion, dtype: float64

# %% [markdown]
# Sin embargo, el dataset se encuentra desbalanceado. El género con menos películas es el Sci-Fi (5.18%) y el que tiene más información es el de Drama (34.45%).

# %% [markdown]
# # **Preprocesamiento**
#
#   - Limpiar el texto: minúsculas, eliminar símbolos, stopwords, etc.
#   - Aplicar vectorización con TF-IDF, CountVectorizer o embeddings.
#   - Crear las siguientes variables objetivo:
#     - Género (multiclase)
#     - Fecha de estreno (agrupar por décadas, por ejemplo: 1990s, 2000s, 2010s, 2020s...)
#     - Puntuación (variable continua)

# %% [markdown]
# # **Modelado**
#
#   - Entrenar tres modelos de clasificación, uno por cada variable objetivo.
#   - Probar al menos dos algoritmos por modelo.
#   - Comparar sus métricas (accuracy, F1-score, matriz de confusión...).
#   - Justificar la elección del algoritmo final.

# %% [markdown]
# # **Visualización**
#
#   - Comentar los resultados obtenidos.
#   - ¿Qué variable fue más fácil de predecir? ¿El título o la sinopsis aporta más información?
#   - ¿Cuántas películas se necesitan por clase para que el modelo generalice bien?
